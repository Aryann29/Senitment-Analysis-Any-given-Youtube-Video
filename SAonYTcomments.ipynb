# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryann29/Senitment-Analysis-Any-given-Youtube-Video/blob/main/SAonYTcomments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 50.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 25.6 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline
classifier = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
# !pip install pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 2.9 MB/s eta 0:00:00
# ...

# %%
import os

import googleapiclient.discovery

def google_api(id):
    os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"

    api_service_name = "youtube"
    api_version = "v3"
    DEVELOPER_KEY = "AIzaSyDsD0554CikiNUoLIGIl5BvzzeLOw5nkys"

    youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)

    request = youtube.commentThreads().list(
        part="id,snippet",
        maxResults=100,
        order="relevance",
        videoId= id
    )
    response = request.execute()

    return response

from pytube import extract

def parseurl(url):
    id=extract.video_id(url)
    return id 

yourUrl = input("Enter URl of ur video")  

response = google_api(parseurl(yourUrl))
# Out:
# Enter URl of ur videohttps://youtu.be/G93JTwkHzzI

# %%
import pandas as pd 
def create_df_author_comments():
  authorname = []
  comments = []
  for i in range(len(response["items"])):
    authorname.append(response["items"][i]["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"])
    comments.append(response["items"][i]["snippet"]["topLevelComment"]["snippet"]["textOriginal"])
  df = pd.DataFrame(comments, index = authorname,columns=["Comments"])
  return df
df = create_df_author_comments()
df
# Out:
#                                                                  Comments
# Totboy                  This year has been eventful nevertheless, hope...
# Rebel X13               This legit felt like the good old days when re...
# Nooby                   actually one of the best videos i have ever wa...
# Fizzletrie              i like how this isn't overdone, no big edits a...
# Chris Wang              thanks for covering actual things that actuall...
# ...                                                                   ...
# I am Vee                Thank you for doing this and highlighting our ...
# Cosmos Animations       I might just be going insane but it's beginnin...
# Official_key_necklaces  The year feels so short yet many things happen...
# LB303                   this is perfect Rewind of 2022 i ever seen, th...
# zigdoesstuff            Guys we got to blow this up. This is an actual...
#
# [100 rows x 1 columns]

# %%
df = df.reset_index()

# %%
def classify(list):
  results = []
  for i in range(len(list)):
    results.append(classifier(list[i]))
  return results

def res_sep(list):
  res = []
  for i in range(len(a)):
    res.append(df_new["results"][i]['label'])
  return res

# %%
a = classify(df["Comments"])

# %%
df_new = pd.DataFrame(a,columns=["results"])

# %%
df_new.reset_index()
# Out:
#     index                                            results
# 0       0  {'label': 'POSITIVE', 'score': 0.9998812675476...
# 1       1  {'label': 'POSITIVE', 'score': 0.9904282093048...
# 2       2  {'label': 'POSITIVE', 'score': 0.9975690245628...
# 3       3  {'label': 'POSITIVE', 'score': 0.9995162487030...
# 4       4  {'label': 'POSITIVE', 'score': 0.9934284090995...
# ..    ...                                                ...
# 95     95  {'label': 'POSITIVE', 'score': 0.9998418092727...
# 96     96  {'label': 'POSITIVE', 'score': 0.9968722462654...
# 97     97  {'label': 'POSITIVE', 'score': 0.8329223394393...
# 98     98  {'label': 'POSITIVE', 'score': 0.997051477432251}
# 99     99  {'label': 'POSITIVE', 'score': 0.9960182309150...
#
# [100 rows x 2 columns]

# %%
df_new["results"][0]['label']
# Out:
# 'POSITIVE'

# %%
ress = res_sep(a)

# %%
results = pd.DataFrame(ress,columns=["results"])
results.reset_index()
# Out:
#     index   results
# 0       0  POSITIVE
# 1       1  POSITIVE
# 2       2  POSITIVE
# 3       3  POSITIVE
# 4       4  POSITIVE
# ..    ...       ...
# 95     95  POSITIVE
# 96     96  POSITIVE
# 97     97  POSITIVE
# 98     98  POSITIVE
# 99     99  POSITIVE
#
# [100 rows x 2 columns]

# %%
df3 = pd.merge(df,results,left_index=True,right_index=True)

# %%
df3
# Out:
#                      index                                           Comments  \
# 0                   Totboy  This year has been eventful nevertheless, hope...
# 1                Rebel X13  This legit felt like the good old days when re...
# 2                    Nooby  actually one of the best videos i have ever wa...
# 3               Fizzletrie  i like how this isn't overdone, no big edits a...
# 4               Chris Wang  thanks for covering actual things that actuall...
# ..                     ...                                                ...
# 95                I am Vee  Thank you for doing this and highlighting our ...
# 96       Cosmos Animations  I might just be going insane but it's beginnin...
# 97  Official_key_necklaces  The year feels so short yet many things happen...
# 98                   LB303  this is perfect Rewind of 2022 i ever seen, th...
# 99            zigdoesstuff  Guys we got to blow this up. This is an actual...
#
#      results
# 0   POSITIVE
# ...

# %%
positive = df3.results.value_counts(normalize=True)["POSITIVE"]
negative = df3.results.value_counts(normalize=True)["NEGATIVE"]

# %%
print(f"{100*positive}% of comments are Positive and {100*negative}% are Negative")
# Out:
# 88.0% of comments are Positive and 12.0% are Negative
